# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesha0002/flyrankML/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ayesha0002/flyrankStarter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the Refresh / Content Opportunity Scoring lane. My goal is to identify pages that are good candidates for content updates based on their search performance and engagement metrics. This interests me because content teams often have limited time and resources, so prioritizing the pages with the greatest potential impact can improve efficiency. Rather than trying to predict rankings directly, I want to build a system that helps decide which pages should be reviewed first using evidence from the available data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision my work aims to improve is which website pages should be prioritized for content updates. The primary users are SEO specialists or content managers who must decide where to spend their limited time and resources. Based on the ranked recommendations, they can review, update, or optimize the selected pages first. If the recommendations are wrong, they may spend time improving pages with little potential while overlooking pages that could have generated greater improvements in search performance. The goal is to support better prioritization using data rather than replacing human judgment.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import pandas as pd

csv_files = []

for root, dirs, files in os.walk("."):
    for file in files:
        if file.lower().endswith(".csv"):
            csv_files.append(os.path.join(root, file))

if not csv_files:
    print("No CSV files found.")
else:
    print("CSV files found:\n")
    for i, file in enumerate(csv_files):
        print(f"{i+1}. {file}")

    # Load the first CSV automatically
    df = pd.read_csv(csv_files[0])

    print("\nDataset loaded successfully!")
    print("\nShape:", df.shape)

    print("\nColumns:")
    print(df.columns.tolist())

    print("\nFirst 5 rows:")
    display(df.head())
# Out:
# CSV files found:
#
# 1. ./sample_data/california_housing_test.csv
# 2. ./sample_data/california_housing_train.csv
# 3. ./sample_data/mnist_train_small.csv
# 4. ./sample_data/mnist_test.csv
#
# Dataset loaded successfully!
#
# Shape: (3000, 9)
#
# Columns:
# ['longitude', 'latitude', 'housing_median_age', 'total_rooms', 'total_bedrooms', 'population', 'households', 'median_income', 'median_house_value']
#
# First 5 rows:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project will provide decision support by identifying patterns in the available search and content data that may help prioritize pages for content refresh. The findings will be observational and directional, showing associations rather than proving why they exist.
# This project will not prove cause-and-effect relationships, explain how Google's ranking algorithm works, or predict future rankings with certainty. Any conclusions will be limited to the available data and should be interpreted as evidence to guide further review rather than definitive proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
